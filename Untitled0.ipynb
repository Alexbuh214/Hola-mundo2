# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexbuh214/Hola-mundo2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio de hola mundo
# ## hola mundo con python
# python es un lenguaje

# %%
print("hola mundo")
# Out:
# hola mundo

# %% [markdown]
# ## hola mundo con c++
# c++ es un lenguaje

# %%
#include <iostream>
int main() {
    std::cout << "Hola Mundo" << std::endl;
    return 0;
}
# Out:
#   File "/tmp/ipython-input-972762291.py", line 3
#     int main() {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## hola mundo con javascript
# javascript es un lenguaje

# %%
console.log("Hola Mundo"); // Imprime "Hola Mundo" en la consola
# Out:
#   File "/tmp/ipython-input-2483128020.py", line 1
#     console.log("Hola Mundo"); // Imprime "Hola Mundo" en la consola
#                                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## hola mundo con java
# Java es un lenguaje

# %%
public class HolaMundo {
    public static void main(String[] args) {
        System.out.println("Hola Mundo"); // Imprime "Hola Mundo" en la consola
    }
}
